# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # STT707

# %% [markdown]
# Soit une matrice de $n$ observations comportant $p$ mesures chacune
# $
# X_{n \times p} \equiv \{ x_i^j \}, \,\,\, i = 1,2,...,n, \,\,\, j=1,2,...,p
# $
#
# $
# X = \begin{Bmatrix}
#     x_{1}^{1} & x_{1}^{2} & \cdots & x_{1}^{p} \\
#     x_{2}^{1} & x_{2}^{2} & \cdots & x_{2}^{p} \\
#     \vdots & \vdots &\ddots & \vdots \\
#     x_{n}^{1} &x_{n}^{2} & \cdots & x_{n}^{p} \\
#     \end{Bmatrix}
# $

# %%
# fixons les dimensions
n = 10000 # Observations
p = 3 # so we can represent the data in a 3D space

X = np.random.rand(n, p) * 10
print(f'{X[:5, :]}')
print('\t.\t.\t.\n'*3)
print(f'{X[-5:, :]}')
# Out:
# [[9.00045235 5.56123046 5.99247107]
#  [4.22270798 5.61620957 9.5345022 ]
#  [6.02898343 1.73900956 1.76319657]
#  [7.17700029 7.63918007 7.99842899]
#  [5.71801406 1.06241806 3.02078904]]
# 	.	.	.
# 	.	.	.
# 	.	.	.
#
# [[2.21200857 5.01802738 2.63037793]
#  [5.93852725 0.08236761 0.09178765]
#  [4.24009344 7.6500572  2.15077957]
#  [1.85235937 8.2748373  3.78784121]
#  [2.90110397 3.4856247  5.84563523]]

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
